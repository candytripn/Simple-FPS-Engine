# %%
scores = [5, 8, 3, 10, 6]
total = 0
for i in range(len(scores)):
    if i % 2 == 0:       # even index
        total += scores[i]
print(total)
# Out:
# 14

# %%
len(scores)
# Out:
# 5

# %%
for i in range(len(scores)):
    print(f"Index {i} has value {scores[i]}")
# Out:
# Index 0 has value 5
# Index 1 has value 8
# Index 2 has value 3
# Index 3 has value 10
# Index 4 has value 6
